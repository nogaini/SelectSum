# %%
num_frames_to_sample = 5
total_frames = 30
hop = total_frames // (num_frames_to_sample - 1)

# %%
hop
# Out:
# 7

# %%
range(0, total_frames, hop)
# Out:
# range(0, 30, 7)

# %%
for x in range(0, total_frames, hop):
    print(x)
# Out:
# 0
# 7
# 14
# 21
# 28
